# %%
#IPL 2018 Dataset
import pandas as pd
data=pd.read_csv('IPL_2018.csv')

# %%
data.head(15)
# Out:
#              Player  Mat  Inns  Overs  Mdns  Runs_Given  Wkts    BBI  BowlAve  \
# 0   Abhishek Sharma    3     0    0.0     0           0     0      0     0.00
# 1           AD Nath    1     0    0.0     0           0     0      0     0.00
# 2        MA Agarwal   11     0    0.0     0           0     0      0     0.00
# 3          KK Ahmed    1     1    3.0     0          38     0      0     0.00
# 4            MM Ali    5     5   13.1     0          97     3  41275    32.33
# 5       CJ Anderson    3     3    8.4     0         115     3  17199    38.33
# 6      Ankit Sharma    1     1    1.0     0          11     0      0     0.00
# 7     Anureet Singh    3     3    4.0     0          42     1  43831    42.00
# 8         JC Archer   10    10   38.5     0         325    15  44621    21.66
# 9          M Ashwin    2     2    7.0     0          53     3  13181    17.66
# 10         R Ashwin   14    14   50.4     0         410    10  43132    41.00
# ...

# %%
data.tail()
# Out:
#            Player  Mat  Inns  Overs  Mdns  Runs_Given  Wkts    BBI  BowlAve  \
# 144     CR Woakes    5     5   18.2     0         190     8  13210    23.75
# 145       MA Wood    1     1    4.0     0          49     0      0     0.00
# 146      SA Yadav   14     0    0.0     0           0     0      0     0.00
# 147      UT Yadav   14    14   53.1     1         418    20  44986    20.90
# 148  Yuvraj Singh    8     2    2.0     0          23     0      0     0.00
#
#       Econ  Batting_Runs  HS  BattingAve      SR  4s  6s  Ct  St
# 144  10.36            17  11        8.50   89.47   1   1   1   0
# 145  12.25             1   1        1.00   33.33   0   0   1   0
# 146   0.00           512  72       36.57  133.33  61  16   8   0
# 147   7.86             3   1        0.75   27.27   0   0   2   0
# 148  11.50            65  20       10.83   89.04   6   2   1   0

# %%
data.columns
# Out:
# Index(['Player', 'Mat', 'Inns', 'Overs', 'Mdns', 'Runs_Given', 'Wkts', 'BBI',
#        'BowlAve', 'Econ', 'Batting_Runs', 'HS', 'BattingAve', 'SR', '4s', '6s',
#        'Ct', 'St'],
#       dtype='object')

# %%
data.groupby('Mat').count()
# Out:
#      Player  Inns  Overs  Mdns  Runs_Given  Wkts  BBI  BowlAve  Econ  \
# Mat
# 1        14    14     14    14          14    14   14       14    14
# 2         6     6      6     6           6     6    6        6     6
# 3         7     7      7     7           7     7    7        7     7
# 4        10    10     10    10          10    10   10       10    10
# 5         7     7      7     7           7     7    7        7     7
# 6        14    14     14    14          14    14   14       14    14
# 7        10    10     10    10          10    10   10       10    10
# 8         6     6      6     6           6     6    6        6     6
# 9         8     8      8     8           8     8    8        8     8
# 10        4     4      4     4           4     4    4        4     4
# 11        7     7      7     7           7     7    7        7     7
# 12        6     6      6     6           6     6    6        6     6
# ...

# %%
data.groupby('Mat').count()['Player'].sort_values(ascending=True).plot(kind='bar')

# %%
data.groupby('Mat').count()
# Out:
#      Player  Inns  Overs  Mdns  Runs_Given  Wkts  BBI  BowlAve  Econ  \
# Mat
# 1        14    14     14    14          14    14   14       14    14
# 2         6     6      6     6           6     6    6        6     6
# 3         7     7      7     7           7     7    7        7     7
# 4        10    10     10    10          10    10   10       10    10
# 5         7     7      7     7           7     7    7        7     7
# 6        14    14     14    14          14    14   14       14    14
# 7        10    10     10    10          10    10   10       10    10
# 8         6     6      6     6           6     6    6        6     6
# 9         8     8      8     8           8     8    8        8     8
# 10        4     4      4     4           4     4    4        4     4
# 11        7     7      7     7           7     7    7        7     7
# 12        6     6      6     6           6     6    6        6     6
# ...

# %%
import matplotlib.pyplot as plt
d1=data.groupby('Mat').size().plot.pie(y='Mat')

# %%
data.groupby('6s').size()
# Out:
# 6s
# 0     56
# 1     21
# 2      5
# 3      1
# 4      8
# 5      9
# 6      7
# 7      2
# 8      5
# 9      2
# 10     4
# 11     4
# 12     2
# 13     1
# 14     2
# 16     2
# 17     1
# 18     2
# 19     1
# 21     3
# 23     1
# 24     1
# 27     1
# 28     1
# 30     2
# 31     1
# 32     1
# 34     1
# 35     1
# 37     1
# dtype: int64

# %%
data.groupby('6s').size().plot(kind='bar',figsize=(10,5))

# %%
data.groupby('6s').size().plot.pie(y='6s',figsize=(9,8))

# %%
data.groupby('4s').size()
# Out:
# 4s
# 0     40
# 1     18
# 2     10
# 3     11
# 4      4
# 5      6
# 6      5
# 7      3
# 8      3
# 9      3
# 10     1
# 11     2
# 13     2
# 14     1
# 16     2
# 17     3
# 18     1
# 20     3
# 22     5
# 23     1
# 24     1
# 25     1
# 26     2
# 27     1
# 29     1
# 30     3
# 32     1
# 39     2
# 40     1
# 44     1
# 46     1
# 49     1
# 52     2
# 53     1
# 56     1
# 59     1
# 61     1
# 63     1
# 66     1
# 68     1
# dtype: int64

# %%
data.groupby('6s').size().plot(kind='bar',figsize=(10,5))

# %%
data.groupby('4s').size().plot(kind='pie',figsize=(9,8))

# %%
data.groupby('Runs_Given').size().plot(kind='bar',figsize=(10,5))
